# %%
import pandas as pd

# %%
rbis21 = pd.read_csv("data/rbis_21_data.csv")

# %%
rbis21
# Out:
#        INSPTN_OPS_DETAIL INSPTN_TYP_CD INSP_INSPECT_DT INSPECTING_UNIT_CODE  \
# 0               13772069          RISK      08/07/2020                 B048
# 1               13772067          RISK      08/07/2020                 B048
# 2               13772068          RISK      08/07/2020                 B048
# 3               13772071          RISK      08/07/2020                 B048
# 4               13772070          RISK      08/07/2020                 B048
# ...                  ...           ...             ...                  ...
# 14875           16805879          RISK      08/02/2021                 E021
# 14876           16810082          RISK      08/02/2021                 E326
# 14877           16814527          RISK      08/02/2021                 E280
# 14878           16814519          RISK      08/02/2021                 L003
# 14879           16807403          RISK      08/02/2021                 E159
#
#        BLDG_CURRENT_BIN_FK BOROUGH  LATITUDE  LONGITUDE  COMMUNITYDISTRICT  \
# 0                  3026632      BK  40.66274  -73.98475              307.0
# 1                  3025908      BK  40.66667  -73.98058              306.0
# 2                  3126361      BK       NaN        NaN                NaN
# 3                  3421702      BK  40.63385  -73.98213              312.0
# 4                  3855166      BK       NaN        NaN                NaN
# ...                    ...     ...       ...        ...                ...
# 14875              1019486      MN  40.74974  -73.97647              106.0
# 14876              4452735      QN  40.74029  -73.76068              411.0
# 14877              3029647      BK  40.67209  -73.96136              308.0
# 14878              1009397      MN  40.73508  -73.99218              102.0
# 14879              5051105      SI  40.58194  -74.09887              502.0
#
#        CITYCOUNCILDISTRICT           BBL             Location 1
# 0                     39.0  3.011040e+09  (40.66274, -73.98475)
# 1                     39.0  3.010900e+09  (40.66667, -73.98058)
# 2                      NaN           NaN                    NaN
# 3                     44.0  3.053790e+09  (40.63385, -73.98213)
# 4                      NaN           NaN                    NaN
# ...                    ...           ...                    ...
# 14875                  4.0  1.008950e+09  (40.74974, -73.97647)
# 14876                 23.0  4.076360e+09  (40.74029, -73.76068)
# 14877                 35.0  3.011800e+09  (40.67209, -73.96136)
# 14878                  2.0  1.005710e+09  (40.73508, -73.99218)
# 14879                 50.0  5.035590e+09  (40.58194, -74.09887)
#
# [14880 rows x 12 columns]

# %%
## Okay, lets start cleaning and tidying. 
## first lets make these column headers more simple and easy to work with.
## making column headers all lower case and more clear

# %%
rbis21.rename(columns = {"INSPTN_OPS_DETAIL": "inspection_id", 
                          "INSPTN_TYP_CD" : "inspection_type", 
                          "INSP_INSPECT_DT" : "inspection_date",
                         "INSPECTING_UNIT_CODE" : "inspecting_unit",
                         "BLDG_CURRENT_BIN_FK" : "building_id",
                         "BOROUGH" : "borough",
                         "LATITUDE" : "latitude",
                         "LONGITUDE" : "longitude",
                         "COMMUNITYDISTRICT" : "community_district",
                         "CITYCOUNCILDISTRICT" : "council_district",
                         "BBL" : "bbl",
                         "Location 1" : "location"}, inplace = True)

# %%
## checking for duplicates
rbis21[rbis21.duplicated()]
# Out:
# Empty DataFrame
# Columns: [inspection_id, inspection_type, inspection_date, inspecting_unit, building_id, borough, latitude, longitude, community_district, council_district, bbl, location]
# Index: []

# %%
## great, no duplicates. 
## what about NaN's?
rbis21.isna().any()
# Out:
# inspection_id         False
# inspection_type       False
# inspection_date       False
# inspecting_unit       False
# building_id           False
# borough               False
# latitude               True
# longitude              True
# community_district     True
# council_district       True
# bbl                    True
# location               True
# dtype: bool

# %%
## community district is important to analysis on a granular level. checking how many NaN's there are in that column
rbis21[rbis21["community_district"].isna()]
# Out:
#        inspection_id inspection_type inspection_date inspecting_unit  \
# 2           13772068            RISK      08/07/2020            B048
# 4           13772070            RISK      08/07/2020            B048
# 48          13968293            RISK      08/31/2020            L129
# 84          14012577            RISK      09/02/2020            E261
# 111         14023901            RISK      09/03/2020            L046
# ...              ...             ...             ...             ...
# 14017       16774562            RISK      07/27/2021            L076
# 14083       16768503            RISK      07/27/2021            E221
# 14501       16783613            RISK      07/29/2021            L102
# 14735       16810348            RISK      08/02/2021            L010
# 14752       16805611            RISK      08/02/2021            L152
#
#        building_id borough  latitude  longitude  community_district  \
# 2          3126361      BK       NaN        NaN                 NaN
# 4          3855166      BK       NaN        NaN                 NaN
# 48         4115064      QN       NaN        NaN                 NaN
# 84         4438278      QN       NaN        NaN                 NaN
# 111        2128216      BX       NaN        NaN                 NaN
# ...            ...     ...       ...        ...                 ...
# 14017      5811532      SI       NaN        NaN                 NaN
# 14083      3414037      BK       NaN        NaN                 NaN
# 14501      3048919      BK       NaN        NaN                 NaN
# 14735      1090819      MN       NaN        NaN                 NaN
# 14752      4864460      QN       NaN        NaN                 NaN
#
#        council_district  bbl location
# 2                   NaN  NaN      NaN
# 4                   NaN  NaN      NaN
# 48                  NaN  NaN      NaN
# 84                  NaN  NaN      NaN
# 111                 NaN  NaN      NaN
# ...                 ...  ...      ...
# 14017               NaN  NaN      NaN
# 14083               NaN  NaN      NaN
# 14501               NaN  NaN      NaN
# 14735               NaN  NaN      NaN
# 14752               NaN  NaN      NaN
#
# [85 rows x 12 columns]

# %%
## 85 rows out of a total of 14880 rows
85 / 14880
# Out:
# 0.00571236559139785

# %%
## thats less than one percent, scraping that data would be a very long process without statistical significance,
## so I feel good about letting it go.

# %%
## Now, a bunch of these columns are unnecessary extras, lets remove them to get a cleaner view

# %%
rbis21 = rbis21[["inspection_id",
                 "inspection_date",
                  "inspecting_unit",
                  "building_id",
                  "borough", 
                  "community_district",
                  "council_district",
                  "bbl"]]

# %%
rbis21
# Out:
#        inspection_id inspection_date inspecting_unit  building_id borough  \
# 0           13772069      08/07/2020            B048      3026632      BK
# 1           13772067      08/07/2020            B048      3025908      BK
# 2           13772068      08/07/2020            B048      3126361      BK
# 3           13772071      08/07/2020            B048      3421702      BK
# 4           13772070      08/07/2020            B048      3855166      BK
# ...              ...             ...             ...          ...     ...
# 14875       16805879      08/02/2021            E021      1019486      MN
# 14876       16810082      08/02/2021            E326      4452735      QN
# 14877       16814527      08/02/2021            E280      3029647      BK
# 14878       16814519      08/02/2021            L003      1009397      MN
# 14879       16807403      08/02/2021            E159      5051105      SI
#
#        community_district  council_district           bbl
# 0                   307.0              39.0  3.011040e+09
# 1                   306.0              39.0  3.010900e+09
# 2                     NaN               NaN           NaN
# 3                   312.0              44.0  3.053790e+09
# 4                     NaN               NaN           NaN
# ...                   ...               ...           ...
# 14875               106.0               4.0  1.008950e+09
# 14876               411.0              23.0  4.076360e+09
# 14877               308.0              35.0  3.011800e+09
# 14878               102.0               2.0  1.005710e+09
# 14879               502.0              50.0  5.035590e+09
#
# [14880 rows x 8 columns]

# %%
## what we really care about here is the number of inspections by community district, so lets take a value count
## and save it into a new dataframe

# %%
rbis21_cd = rbis21["community_district"].value_counts()

# %%
rbis21_cd
# Out:
# 501.0    800
# 414.0    587
# 503.0    586
# 407.0    538
# 502.0    489
#         ...
# 484.0     11
# 228.0      4
# 481.0      2
# 227.0      1
# 595.0      1
# Name: community_district, Length: 64, dtype: int64

# %%
## Lets store this into a new dataframe

# %%
rbis21_cd = rbis21_cd.to_frame().reset_index()

# %%
rbis21_cd
# Out:
#     index  community_district
# 0   501.0                 800
# 1   414.0                 587
# 2   503.0                 586
# 3   407.0                 538
# 4   502.0                 489
# ..    ...                 ...
# 59  484.0                  11
# 60  228.0                   4
# 61  481.0                   2
# 62  227.0                   1
# 63  595.0                   1
#
# [64 rows x 2 columns]

# %%
## gotta rename the columns
rbis21_cd.rename(columns = {"index": "community_district",
                           "community_district": "total_inspections"}, inplace = True)
rbis21_cd.index.name = 'index'

# %%
rbis21_cd
# Out:
#        community_district  total_inspections
# index
# 0                   501.0                800
# 1                   414.0                587
# 2                   503.0                586
# 3                   407.0                538
# 4                   502.0                489
# ...                   ...                ...
# 59                  484.0                 11
# 60                  228.0                  4
# 61                  481.0                  2
# 62                  227.0                  1
# 63                  595.0                  1
#
# [64 rows x 2 columns]

# %%
## Now we need to compare these numbers to the toatl numbers of structural fires
## let's import the fire dispatch data for structural fires during the same time frame

# %%
fires21 = pd.read_csv("data/fire_dispatch21.csv")

# %%
fires21
# Out:
#        STARFIRE_INCIDENT_ID       INCIDENT_DATETIME ALARM_BOX_BOROUGH  \
# 0          2021516050140014  08/02/2020 12:19:45 AM          BROOKLYN
# 1          2021522730120050  08/02/2020 12:27:38 AM             BRONX
# 2          2021515830110081  08/02/2020 02:15:20 AM         MANHATTAN
# 3          2021516050110122  08/02/2020 03:59:49 AM         MANHATTAN
# 4          2021527670120182  08/02/2020 04:10:13 AM             BRONX
# ...                     ...                     ...               ...
# 24381      2121306940941080  08/01/2021 10:52:59 PM          BROOKLYN
# 24382      2121313230111090  08/01/2021 11:01:48 PM         MANHATTAN
# 24383      2121327480720900  08/01/2021 11:04:27 PM             BRONX
# 24384      2121329920320910  08/01/2021 11:12:02 PM             BRONX
# 24385      2121315580110000  08/01/2021 11:59:54 PM         MANHATTAN
#
#        ALARM_BOX_NUMBER             ALARM_BOX_LOCATION INCIDENT_BOROUGH  \
# 0                  1605           UTICA AVE & CROWN ST         BROOKLYN
# 1                  2273       GRAND CONCOURSE & 153 ST            BRONX
# 2                  1583              BROADWAY & 139 ST        MANHATTAN
# 3                  1605         POWELL BLVD & W 142 ST        MANHATTAN
# 4                  2767            FULTON AVE & 171 ST            BRONX
# ...                 ...                            ...              ...
# 24381               694        MYRTLE AVE & THROOP AVE         BROOKLYN
# 24382              1323              BROADWAY & 108 ST        MANHATTAN
# 24383              2748        WASHINGTON AVE & 170 ST            BRONX
# 24384              2992  HARRISON AVE OPP KINGSLAND PL            BRONX
# 24385              1558              BROADWAY & 135 ST        MANHATTAN
#
#        ZIPCODE  POLICEPRECINCT  CITYCOUNCILDISTRICT  COMMUNITYDISTRICT  ...  \
# 0      11213.0            71.0                 41.0              309.0  ...
# 1      10451.0            44.0                 17.0              204.0  ...
# 2      10031.0            30.0                  7.0              109.0  ...
# 3      10030.0            32.0                  9.0              110.0  ...
# 4      10456.0            42.0                 16.0              203.0  ...
# ...        ...             ...                  ...                ...  ...
# 24381  11206.0            79.0                 36.0              303.0  ...
# 24382  10025.0            24.0                  7.0              107.0  ...
# 24383  10456.0            42.0                 16.0              203.0  ...
# 24384  10453.0            46.0                 14.0              205.0  ...
# 24385      NaN             NaN                  NaN                NaN  ...
#
#        FIRST_ACTIVATION_DATETIME  FIRST_ON_SCENE_DATETIME  \
# 0         08/02/2020 12:20:29 AM   08/02/2020 12:22:50 AM
# 1         08/02/2020 12:28:17 AM   08/02/2020 12:32:27 AM
# 2         08/02/2020 02:16:13 AM   08/02/2020 02:19:11 AM
# 3         08/02/2020 04:01:15 AM   08/02/2020 04:04:49 AM
# 4         08/02/2020 04:11:16 AM   08/02/2020 04:16:14 AM
# ...                          ...                      ...
# 24381     08/01/2021 10:53:44 PM   08/01/2021 10:55:35 PM
# 24382     08/01/2021 11:02:31 PM   08/01/2021 11:05:37 PM
# 24383     08/01/2021 11:04:50 PM   08/01/2021 11:08:45 PM
# 24384     08/01/2021 11:12:35 PM   08/01/2021 11:18:04 PM
# 24385     08/02/2021 12:00:45 AM                      NaN
#
#       INCIDENT_CLOSE_DATETIME VALID_DISPATCH_RSPNS_TIME_INDC  \
# 0      08/02/2020 12:30:37 AM                              N
# 1      08/02/2020 12:45:51 AM                              N
# 2      08/02/2020 06:29:37 AM                              N
# 3      08/02/2020 04:33:20 AM                              N
# 4      08/02/2020 04:26:59 AM                              N
# ...                       ...                            ...
# 24381  08/01/2021 11:25:38 PM                              N
# 24382  08/01/2021 11:18:54 PM                              N
# 24383  08/01/2021 11:58:32 PM                              N
# 24384  08/01/2021 11:57:13 PM                              N
# 24385  08/02/2021 12:00:45 AM                              N
#
#       VALID_INCIDENT_RSPNS_TIME_INDC INCIDENT_RESPONSE_SECONDS_QY  \
# 0                                  Y                          185
# 1                                  Y                          289
# 2                                  Y                          231
# 3                                  Y                          300
# 4                                  Y                          361
# ...                              ...                          ...
# 24381                              Y                          156
# 24382                              Y                          229
# 24383                              Y                          258
# 24384                              Y                          362
# 24385                              N                            0
#
#       INCIDENT_TRAVEL_TM_SECONDS_QY  ENGINES_ASSIGNED_QUANTITY  \
# 0                               155                          3
# 1                               265                          3
# 2                               203                         10
# 3                               258                          2
# 4                               317                          3
# ...                             ...                        ...
# 24381                           123                          3
# 24382                           196                          3
# 24383                           242                          4
# 24384                           336                          3
# 24385                             0                          4
#
#       LADDERS_ASSIGNED_QUANTITY OTHER_UNITS_ASSIGNED_QUANTITY
# 0                             2                             1
# 1                             3                             1
# 2                             7                            16
# 3                             2                             1
# 4                             2                             1
# ...                         ...                           ...
# 24381                         2                             1
# 24382                         2                             1
# 24383                         2                             2
# 24384                         2                             1
# 24385                         2                             1
#
# [24386 rows x 29 columns]

# %%
## lets check for dups and Nans before dropping columns that we don't need and renaming columns
fires21[fires21.duplicated()]
# Out:
#        STARFIRE_INCIDENT_ID       INCIDENT_DATETIME         ALARM_BOX_BOROUGH  \
# 13051      2103910000000000  02/08/2021 09:41:00 AM  RICHMOND / STATEN ISLAND
# 13054      2103910000000000  02/08/2021 09:42:00 AM  RICHMOND / STATEN ISLAND
# 13055      2103910000000000  02/08/2021 09:42:00 AM  RICHMOND / STATEN ISLAND
# 13057      2103910000000000  02/08/2021 09:43:00 AM  RICHMOND / STATEN ISLAND
# 13058      2103910000000000  02/08/2021 09:43:00 AM  RICHMOND / STATEN ISLAND
# 16367      2108640000000000  03/27/2021 10:02:00 PM  RICHMOND / STATEN ISLAND
# 16368      2108640000000000  03/27/2021 10:02:00 PM  RICHMOND / STATEN ISLAND
# 16369      2108640000000000  03/27/2021 10:02:00 PM  RICHMOND / STATEN ISLAND
#
#        ALARM_BOX_NUMBER              ALARM_BOX_LOCATION  \
# 13051               996        LOCKMAN AVE & BRABANT ST
# 13054               996        LOCKMAN AVE & BRABANT ST
# 13055               996        LOCKMAN AVE & BRABANT ST
# 13057               996        LOCKMAN AVE & BRABANT ST
# 13058               996        LOCKMAN AVE & BRABANT ST
# 16367              4391  PLEASANT PLAINS AVE & AMBOY RD
# 16368              4391  PLEASANT PLAINS AVE & AMBOY RD
# 16369              4391  PLEASANT PLAINS AVE & AMBOY RD
#
#                INCIDENT_BOROUGH  ZIPCODE  POLICEPRECINCT  CITYCOUNCILDISTRICT  \
# 13051  RICHMOND / STATEN ISLAND  10303.0           121.0                 49.0
# 13054  RICHMOND / STATEN ISLAND  10303.0           121.0                 49.0
# 13055  RICHMOND / STATEN ISLAND  10303.0           121.0                 49.0
# 13057  RICHMOND / STATEN ISLAND  10303.0           121.0                 49.0
# 13058  RICHMOND / STATEN ISLAND  10303.0           121.0                 49.0
# 16367  RICHMOND / STATEN ISLAND  10309.0           123.0                 51.0
# 16368  RICHMOND / STATEN ISLAND  10309.0           123.0                 51.0
# 16369  RICHMOND / STATEN ISLAND  10309.0           123.0                 51.0
#
#        COMMUNITYDISTRICT  ...  FIRST_ACTIVATION_DATETIME  \
# 13051              501.0  ...                        NaN
# 13054              501.0  ...                        NaN
# 13055              501.0  ...                        NaN
# 13057              501.0  ...                        NaN
# 13058              501.0  ...                        NaN
# 16367              503.0  ...                        NaN
# 16368              503.0  ...                        NaN
# 16369              503.0  ...                        NaN
#
#        FIRST_ON_SCENE_DATETIME INCIDENT_CLOSE_DATETIME  \
# 13051                      NaN  02/08/2021 09:50:00 AM
# 13054                      NaN  02/08/2021 09:50:00 AM
# 13055                      NaN  02/08/2021 09:50:00 AM
# 13057                      NaN  02/08/2021 09:49:00 AM
# 13058                      NaN  02/08/2021 09:49:00 AM
# 16367                      NaN  03/27/2021 10:04:00 PM
# 16368                      NaN  03/27/2021 10:04:00 PM
# 16369                      NaN  03/27/2021 10:04:00 PM
#
#       VALID_DISPATCH_RSPNS_TIME_INDC VALID_INCIDENT_RSPNS_TIME_INDC  \
# 13051                              N                              N
# 13054                              N                              N
# 13055                              N                              N
# 13057                              N                              N
# 13058                              N                              N
# 16367                              N                              N
# 16368                              N                              N
# 16369                              N                              N
#
#       INCIDENT_RESPONSE_SECONDS_QY INCIDENT_TRAVEL_TM_SECONDS_QY  \
# 13051                            0                             0
# 13054                            0                             0
# 13055                            0                             0
# 13057                            0                             0
# 13058                            0                             0
# 16367                            0                             0
# 16368                            0                             0
# 16369                            0                             0
#
#        ENGINES_ASSIGNED_QUANTITY LADDERS_ASSIGNED_QUANTITY  \
# 13051                          0                         0
# 13054                          0                         0
# 13055                          0                         0
# 13057                          0                         0
# 13058                          0                         0
# 16367                          0                         0
# 16368                          0                         0
# 16369                          0                         0
#
#       OTHER_UNITS_ASSIGNED_QUANTITY
# 13051                             0
# 13054                             0
# 13055                             0
# 13057                             0
# 13058                             0
# 16367                             0
# 16368                             0
# 16369                             0
#
# [8 rows x 29 columns]

# %%
fires21.drop_duplicates(subset = None, keep = 'first', inplace = True, ignore_index = False)

# %%
fires21[fires21.duplicated()]
# Out:
# Empty DataFrame
# Columns: [STARFIRE_INCIDENT_ID, INCIDENT_DATETIME, ALARM_BOX_BOROUGH, ALARM_BOX_NUMBER, ALARM_BOX_LOCATION, INCIDENT_BOROUGH, ZIPCODE, POLICEPRECINCT, CITYCOUNCILDISTRICT, COMMUNITYDISTRICT, COMMUNITYSCHOOLDISTRICT, CONGRESSIONALDISTRICT, ALARM_SOURCE_DESCRIPTION_TX, ALARM_LEVEL_INDEX_DESCRIPTION, HIGHEST_ALARM_LEVEL, INCIDENT_CLASSIFICATION, INCIDENT_CLASSIFICATION_GROUP, DISPATCH_RESPONSE_SECONDS_QY, FIRST_ASSIGNMENT_DATETIME, FIRST_ACTIVATION_DATETIME, FIRST_ON_SCENE_DATETIME, INCIDENT_CLOSE_DATETIME, VALID_DISPATCH_RSPNS_TIME_INDC, VALID_INCIDENT_RSPNS_TIME_INDC, INCIDENT_RESPONSE_SECONDS_QY, INCIDENT_TRAVEL_TM_SECONDS_QY, ENGINES_ASSIGNED_QUANTITY, LADDERS_ASSIGNED_QUANTITY, OTHER_UNITS_ASSIGNED_QUANTITY]
# Index: []
#
# [0 rows x 29 columns]

# %%
## check for Nans in the community district column, since that's the value that's important to our analysis
fires21[fires21["COMMUNITYDISTRICT"].isna()]
# Out:
#        STARFIRE_INCIDENT_ID       INCIDENT_DATETIME ALARM_BOX_BOROUGH  \
# 52         2021607500140005  08/03/2020 12:06:43 AM          BROOKLYN
# 157        2021840490150020  08/05/2020 12:06:04 AM            QUEENS
# 244        2021970980140816  08/06/2020 02:42:09 PM          BROOKLYN
# 360        2022181710110492  08/08/2020 11:51:07 AM         MANHATTAN
# 496        2022303020151031  08/10/2020 08:28:48 PM            QUEENS
# ...                     ...                     ...               ...
# 23809      2120484810150080  07/23/2021 03:12:50 AM            QUEENS
# 24062      2120806930211110  07/27/2021 05:57:42 PM         MANHATTAN
# 24079      2120800830411380  07/27/2021 09:45:57 PM         MANHATTAN
# 24165      2121084820150590  07/29/2021 04:44:56 PM            QUEENS
# 24385      2121315580110000  08/01/2021 11:59:54 PM         MANHATTAN
#
#        ALARM_BOX_NUMBER                       ALARM_BOX_LOCATION  \
# 52                  750                CYPRESS AVE & STANHOPE ST
# 157                4049             ST. NICHOLAS AVE & LINDEN ST
# 244                7098            BMT J&M @ FLUSHING AVE & BWAY
# 360                8171         33 ST & 8 AV-PENN TERM-PD OFFICE
# 496                 302            JFK AIRPORT - TERMINALS 1-8->
# ...                 ...                                      ...
# 23809              8481               GATEWAY PARK ROCKAWAY ZONE
# 24062               693             11 AVE BET W 30 ST & W 33 ST
# 24079                83                       WEST ST & VESEY ST
# 24165              8482  RIKERS ISL- PRISON HOSP- 14-14 HAZEN ST
# 24385              1558                        BROADWAY & 135 ST
#
#       INCIDENT_BOROUGH  ZIPCODE  POLICEPRECINCT  CITYCOUNCILDISTRICT  \
# 52            BROOKLYN      NaN             NaN                  NaN
# 157             QUEENS      NaN             NaN                  NaN
# 244           BROOKLYN      NaN             NaN                  NaN
# 360          MANHATTAN      NaN             NaN                  NaN
# 496             QUEENS      NaN             NaN                  NaN
# ...                ...      ...             ...                  ...
# 23809           QUEENS      NaN             NaN                  NaN
# 24062        MANHATTAN      NaN             NaN                  NaN
# 24079        MANHATTAN      NaN             NaN                  NaN
# 24165           QUEENS      NaN             NaN                  NaN
# 24385        MANHATTAN      NaN             NaN                  NaN
#
#        COMMUNITYDISTRICT  ...  FIRST_ACTIVATION_DATETIME  \
# 52                   NaN  ...     08/03/2020 12:08:49 AM
# 157                  NaN  ...     08/05/2020 12:06:57 AM
# 244                  NaN  ...     08/06/2020 02:43:31 PM
# 360                  NaN  ...     08/08/2020 11:53:28 AM
# 496                  NaN  ...     08/10/2020 08:29:38 PM
# ...                  ...  ...                        ...
# 23809                NaN  ...     07/23/2021 03:13:48 AM
# 24062                NaN  ...     07/27/2021 05:58:14 PM
# 24079                NaN  ...     07/27/2021 09:46:57 PM
# 24165                NaN  ...     07/29/2021 04:46:23 PM
# 24385                NaN  ...     08/02/2021 12:00:45 AM
#
#        FIRST_ON_SCENE_DATETIME INCIDENT_CLOSE_DATETIME  \
# 52      08/03/2020 12:09:51 AM  08/03/2020 12:11:50 AM
# 157     08/05/2020 12:08:43 AM  08/05/2020 12:20:34 AM
# 244     08/06/2020 02:46:23 PM  08/06/2020 03:08:39 PM
# 360     08/08/2020 11:57:20 AM  08/08/2020 12:44:52 PM
# 496     08/10/2020 08:37:59 PM  08/10/2020 11:30:58 PM
# ...                        ...                     ...
# 23809   07/23/2021 03:20:30 AM  07/23/2021 04:21:09 AM
# 24062   07/27/2021 06:03:31 PM  07/27/2021 06:35:16 PM
# 24079   07/27/2021 09:50:50 PM  07/27/2021 10:12:42 PM
# 24165   07/29/2021 04:47:44 PM  07/29/2021 05:05:42 PM
# 24385                      NaN  08/02/2021 12:00:45 AM
#
#       VALID_DISPATCH_RSPNS_TIME_INDC VALID_INCIDENT_RSPNS_TIME_INDC  \
# 52                                 N                              Y
# 157                                N                              Y
# 244                                N                              Y
# 360                                N                              Y
# 496                                N                              Y
# ...                              ...                            ...
# 23809                              N                              Y
# 24062                              N                              Y
# 24079                              N                              Y
# 24165                              N                              Y
# 24385                              N                              N
#
#       INCIDENT_RESPONSE_SECONDS_QY INCIDENT_TRAVEL_TM_SECONDS_QY  \
# 52                             188                           137
# 157                            159                           123
# 244                            254                           181
# 360                            373                           250
# 496                            551                           517
# ...                            ...                           ...
# 23809                          460                           402
# 24062                          349                           326
# 24079                          293                           244
# 24165                          168                            92
# 24385                            0                             0
#
#        ENGINES_ASSIGNED_QUANTITY LADDERS_ASSIGNED_QUANTITY  \
# 52                             1                         1
# 157                            3                         2
# 244                            3                         2
# 360                            3                         2
# 496                            6                         3
# ...                          ...                       ...
# 23809                          3                         2
# 24062                          3                         2
# 24079                          1                         1
# 24165                          3                         2
# 24385                          4                         2
#
#       OTHER_UNITS_ASSIGNED_QUANTITY
# 52                                0
# 157                               1
# 244                               1
# 360                               3
# 496                               8
# ...                             ...
# 23809                             3
# 24062                             2
# 24079                             1
# 24165                             4
# 24385                             1
#
# [138 rows x 29 columns]

# %%
##138 rows out of 24386 rows
138 / 24386
# Out:
# 0.00565898466333142

# %%
## Again this is less than one percent of rows. We will keep going 
## now lets drop the columns we don't need, then rename the ones we will be using. 

fires21 = fires21[["STARFIRE_INCIDENT_ID",
                  "INCIDENT_DATETIME",
                  "COMMUNITYDISTRICT"]]

# %%
fires21
# Out:
#        STARFIRE_INCIDENT_ID       INCIDENT_DATETIME  COMMUNITYDISTRICT
# 0          2021516050140014  08/02/2020 12:19:45 AM              309.0
# 1          2021522730120050  08/02/2020 12:27:38 AM              204.0
# 2          2021515830110081  08/02/2020 02:15:20 AM              109.0
# 3          2021516050110122  08/02/2020 03:59:49 AM              110.0
# 4          2021527670120182  08/02/2020 04:10:13 AM              203.0
# ...                     ...                     ...                ...
# 24381      2121306940941080  08/01/2021 10:52:59 PM              303.0
# 24382      2121313230111090  08/01/2021 11:01:48 PM              107.0
# 24383      2121327480720900  08/01/2021 11:04:27 PM              203.0
# 24384      2121329920320910  08/01/2021 11:12:02 PM              205.0
# 24385      2121315580110000  08/01/2021 11:59:54 PM                NaN
#
# [24378 rows x 3 columns]

# %%
## okay now lets rename those columns

# %%
fires21.rename(columns = {'STARFIRE_INCIDENT_ID': 'incident_id',
                                   'INCIDENT_DATETIME': 'datetime',
                                   'COMMUNITYDISTRICT': 'community_district'}, inplace = True)
# Out:
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
fires21
# Out:
#             incident_id                datetime  community_district
# 0      2021516050140014  08/02/2020 12:19:45 AM               309.0
# 1      2021522730120050  08/02/2020 12:27:38 AM               204.0
# 2      2021515830110081  08/02/2020 02:15:20 AM               109.0
# 3      2021516050110122  08/02/2020 03:59:49 AM               110.0
# 4      2021527670120182  08/02/2020 04:10:13 AM               203.0
# ...                 ...                     ...                 ...
# 24381  2121306940941080  08/01/2021 10:52:59 PM               303.0
# 24382  2121313230111090  08/01/2021 11:01:48 PM               107.0
# 24383  2121327480720900  08/01/2021 11:04:27 PM               203.0
# 24384  2121329920320910  08/01/2021 11:12:02 PM               205.0
# 24385  2121315580110000  08/01/2021 11:59:54 PM                 NaN
#
# [24378 rows x 3 columns]

# %%
## lets check the value counts to get numbers of actual structural fires in each community district for that year
